# %%
import utils
import loader

# Se usan las trazas de Simva o las de Scorm
use_scorm = False

files_path = "./trazas/simva/"
cols_to_drop = ["stored", "id", "version", "actor.account.homePage", "authority.name", "authority.homePage", "context.contextActivities.category", "context.registration", "object.definition.name.en-US", "object.definition.description.en-US", "object.definition.type", "verb.display.en-US", "verb.id", "object.objectType", "result.response", "result.score.scaled", "result.completion", "result.success"]

if use_scorm:
	files_path = "./trazas/scorm/"
	cols_to_drop = ["verb.display.en-US", "id", "stored", "version", "actor.objectType", "actor.account.homePage", "result.success", "result.completion", "context.registration", "authority.objectType", "authority.account.homePage", "authority.account.name", "authority.name", "object.definition.description.en-US", "object.definition.name.en-US", "object.objectType", "context.contextActivities.category"]

files_extension = "json"


############################
# Datos comunes
# Sacado de los JSONs
############################
df, df_list = loader.load_all_files(files_path, files_extension, "timestamp", cols_to_drop, use_scorm)
n_users = len(df_list)

display(df)
print(n_users)
# Out:
#                             timestamp             actor.account.name Chat  \
# 0    2025-05-17 07:40:17.326000+00:00  6818e721fbe4c00023c50add_andr  NaN
# 1    2025-05-17 07:40:17.441000+00:00  6818e721fbe4c00023c50add_andr  NaN
# 2    2025-05-17 07:40:20.513000+00:00  6818e721fbe4c00023c50add_andr  NaN
# 3    2025-05-17 07:40:21.878000+00:00  6818e721fbe4c00023c50add_andr  NaN
# 4    2025-05-17 07:40:22.530000+00:00  6818e721fbe4c00023c50add_andr  NaN
# ...                               ...                            ...  ...
# 1599 2025-05-17 07:53:39.199000+00:00  6818e721fbe4c00023c50add_fcko  NaN
# 1600 2025-05-17 07:53:40.703000+00:00  6818e721fbe4c00023c50add_fcko  NaN
# 1601 2025-05-17 07:53:41.574000+00:00  6818e721fbe4c00023c50add_fcko  NaN
# 1602 2025-05-17 07:53:41.574000+00:00  6818e721fbe4c00023c50add_fcko  NaN
# 1603 2025-05-17 07:53:41.781000+00:00  6818e721fbe4c00023c50add_fcko  NaN
#
#               object.id       Object Closing                       Node  \
# 0          SessionStart          NaN     NaN                        NaN
# 1            EnterScene          NaN     NaN                        NaN
# 2            EnterScene          NaN     NaN                        NaN
# 3     ObjectInteraction  loginButton     NaN                        NaN
# 4     ObjectInteraction  loginButton     NaN                        NaN
# ...                 ...          ...     ...                        ...
# 1599          DialogEnd          NaN     NaN  Scene7Bedroom.call.thanks
# 1600         EnterScene          NaN     NaN                        NaN
# 1601            GameEnd          NaN     NaN                        NaN
# 1602         SessionEnd          NaN     NaN                        NaN
# 1603         SessionEnd          NaN     NaN                        NaN
#
#               Scene Method Response  ...  \
# 0               NaN    NaN      NaN  ...
# 1        TitleScene    NaN      NaN  ...
# 2        LoginScene    NaN      NaN  ...
# 3               NaN    NaN      NaN  ...
# 4               NaN    NaN      NaN  ...
# ...             ...    ...      ...  ...
# 1599            NaN    NaN      NaN  ...
# 1600  TextOnlyScene    NaN      NaN  ...
# 1601            NaN    NaN      NaN  ...
# 1602            NaN    NaN      NaN  ...
# 1603            NaN    NaN      NaN  ...
#
#                                             Dialog.text Sexuality Gender  \
# 0                                                   NaN       NaN    NaN
# 1                                                   NaN       NaN    NaN
# 2                                                   NaN       NaN    NaN
# 3                                                   NaN       NaN    NaN
# 4                                                   NaN       NaN    NaN
# ...                                                 ...       ...    ...
# 1599  A partir de ahora tendré más cuidado. Gracias ...       NaN    NaN
# 1600                                                NaN       NaN    NaN
# 1601                                                NaN       NaN    NaN
# 1602                                                NaN       NaN    NaN
# 1603                                                NaN       NaN    NaN
#
#      PointerY  PointerX  Liked EndingDay  TimesListened  Explained  Ending
# 0         NaN       NaN    NaN       NaN            NaN        NaN     NaN
# 1         NaN       NaN    NaN       NaN            NaN        NaN     NaN
# 2         NaN       NaN    NaN       NaN            NaN        NaN     NaN
# 3         NaN       NaN    NaN       NaN            NaN        NaN     NaN
# 4         NaN       NaN    NaN       NaN            NaN        NaN     NaN
# ...       ...       ...    ...       ...            ...        ...     ...
# 1599      NaN       NaN    NaN       NaN            NaN        NaN     NaN
# 1600      NaN       NaN    NaN       NaN            NaN        NaN     NaN
# 1601      NaN       NaN    NaN       NaN            NaN       None  routeA
# 1602      NaN       NaN    NaN       NaN            NaN        NaN     NaN
# 1603      NaN       NaN    NaN       NaN            NaN        NaN     NaN
#
# [1604 rows x 21 columns]
# 2
